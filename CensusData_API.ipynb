19363', '19365', '19366', '19367', '19369', '19370', '19371', '19372', '19373', '19374', '19375', '19376', '19380', '19381', '19382', '19390', '19395', '19397', '19398', '19399', '19401', '19403', '19404', '19405', '19406', '19407', '19408', '19409', '19420', '19421', '19422', '19423', '19425', '19426', '19428', '19430', '19432', '19435', '19436', '19437', '19438', '19440', '19442', '19443', '19444', '19446', '19450', '19451', '19452', '19453', '19454', '19456', '19457', '19460', '19462', '19464', '19465', '19468', '19470', '19472', '19473', '19474', '19475', '19477', '19478', '19480', '19481', '19482', '19484', '19485', '19486', '19490', '19492', '19505', '19520', '19525', '19701', '19702', '19703', '19706', '19707', '19708', '19709', '19710', '19711', '19713', '19714', '19715', '19716', '19717', '19720', '19730', '19731', '19732', '19733', '19734', '19735', '19736', '19801', '19802', '19803', '19804', '19805', '19806', '19807', '19808', '19809', '19810', '19850', '19880', '19899', '21901', '21902', '21903', '21904', '21911', '21912', '21913', '21914', '21915', '21916', '21917', '21918', '21919', '21920', '21921', '21922', '21930']

# --- 2. CONFIGURATION MAPS ---
TABS_CONFIG = {
    "Age_Sex": {
        "endpoint": "subject",
        "mapping": {
            "S0101_C01_001E": "Total Population",
            "S0101_C01_002E": "Total!!Age!!Under 5",
            "S0101_C01_003E": "Total!!Age!!5 to 9",
            "S0101_C01_004E": "Total!!Age!!10 to 14",
            "S0101_C01_005E": "Total!!Age!!15 to 19",
            "S0101_C03_001E": "Male!!Total",
            "S0101_C03_002E": "Male!!Age!!Under 5",
            "S0101_C03_003E": "Male!!Age!!5 to 9",
            "S0101_C03_004E": "Male!!Age!!10 to 14",
            "S0101_C03_005E": "Male!!Age!!15 to 19",
            "S0101_C05_001E": "Female!!Total",
            "S0101_C05_002E": "Female!!Age!!Under 5",
            "S0101_C05_003E": "Female!!Age!!5 to 9",
            "S0101_C05_004E": "Female!!Age!!10 to 14",
            "S0101_C05_005E": "Female!!Age!!15 to 19"
        }
    },
    "Income": {
        "endpoint": "subject",
        "mapping": {
            "S1901_C01_001E": "Households!!Total",
            "S1901_C01_002E": "Households!!Less than $10k",
            "S1901_C01_003E": "Households!!$10k to $14,999",
            "S1901_C01_004E": "Households!!$15k to $24,999",
            "S1901_C01_005E": "Households!!$25k to $34,999",
            "S1901_C01_006E": "Households!!$35k to $49,999",
            "S1901_C01_007E": "Households!!$50k to $74,999",
            "S1901_C01_008E": "Households!!$75k to $99,999",
            "S1901_C01_009E": "Households!!$100k to $149,999",
            "S1901_C01_010E": "Households!!$150k to $199,999",
            "S1901_C01_011E": "Households!!$200k or more",
            "S1901_C01_012E": "Median income (dollars)",
            "S1901_C01_013E": "Mean income (dollars)"
        }
    },
    "Race": {
        "endpoint": "profile",
        "mapping": {
            "DP05_0037E": "Est!!White",
            "DP05_0037PE": "Pct!!White",
            "DP05_0038E": "Est!!Black or African American",
            "DP05_0038PE": "Pct!!Black or African American",
            "DP05_0039E": "Est!!AIAN",
            "DP05_0039PE": "Pct!!AIAN",
            "DP05_0047E": "Est!!Asian",
            "DP05_0047PE": "Pct!!Asian",
            "DP05_0055E": "Est!!NHPI",
            "DP05_0055PE": "Pct!!NHPI",
            "DP05_0060E": "Est!!Other Race",
            "DP05_0060PE": "Pct!!Other Race",
            "DP05_0061E": "Est!!Two or More",
            "DP05_0061PE": "Pct!!Two or More"
        }
    },
    "Poverty": {
        "endpoint": "subject",
        "mapping": {
            "S1701_C01_002E": "Total!!Under 18 years",
            "S1701_C01_003E": "Total!!Under 5 years",
            "S1701_C01_004E": "Total!!5 to 17 years",
            "S1701_C01_005E": "Total!!Related children under 18",
            "S1701_C01_011E": "Total!!Male",
            "S1701_C01_012E": "Total!!Female",
            "S1701_C01_013E": "Total!!White",
            "S1701_C01_014E": "Total!!Black",
            "S1701_C01_015E": "Total!!AIAN",
            "S1701_C01_016E": "Total!!Asian",
            "S1701_C01_017E": "Total!!NHPI",
            "S1701_C01_018E": "Total!!Other Race",
            "S1701_C01_019E": "Total!!Two or More",
            "S1701_C02_003E": "Below Poverty!!Under 5 years",
            "S1701_C02_004E": "Below Poverty!!5 to 17 years",
            "S1701_C03_002E": "Pct Below Poverty!!Under 18 years",
            "S1701_C03_003E": "Pct Below Poverty!!Under 5 years",
            "S1701_C03_004E": "Pct Below Poverty!!5 to 17 years"
        }
    },
    "School_Enrollment": {
        "endpoint": "", # Base table
        "mapping": {
            "B14001_001E": "Total!!Pop 3 yrs and over",
            "B14001_002E": "Total!!Enrolled in school",
            "B14001_003E": "Enrolled!!Nursery school/Preschool",
            "B14001_004E": "Enrolled!!Kindergarten",
            "B14001_005E": "Enrolled!!Grade 1 to 4",
            "B14001_006E": "Enrolled!!Grade 5 to 8",
            "B14001_007E": "Enrolled!!Grade 9 to 12"
        }
    },
    "Commuting": {
        "endpoint": "subject",
        "mapping": {
            "S0801_C01_001E": "Total Workers 16+",
            "S0801_C01_002E": "Means: Car/Truck/Van",
            "S0801_C01_003E": "Means: Drove Alone",
            "S0801_C01_004E": "Means: Carpooled",
            "S0801_C01_005E": "Carpool: 2-person",
            "S0801_C01_006E": "Carpool: 3-person",
            "S0801_C01_007E": "Carpool: 4+ person",
            "S0801_C01_009E": "Means: Public Transit",
            "S0801_C01_010E": "Means: Walked",
            "S0801_C01_011E": "Means: Bicycle",
            "S0801_C01_012E": "Means: Other",
            "S0801_C01_013E": "Means: Work from Home",
            "S0801_C01_014E": "Place: In State",
            "S0801_C01_015E": "Place: In County",
            "S0801_C01_016E": "Place: Outside County",
            "S0801_C01_017E": "Place: Outside State",
            "S0801_C01_047E": "Vehicles: Total Workers",
            "S0801_C01_048E": "Vehicles: None",
            "S0801_C01_049E": "Vehicles: 1 Available",
            "S0801_C01_050E": "Vehicles: 2 Available",
            "S0801_C01_051E": "Vehicles: 3+ Available",
            "S0801_C01_052E": "Allocated: Means",
            "S0801_C01_053E": "Allocated: Occupancy",
            "S0801_C01_054E": "Allocated: Place",
            "S0801_C01_056E": "Allocated: Travel Time",
            "S0801_C01_057E": "Allocated: Vehicles"
        }
    },
    "Insurance_Pediatric": {
        "endpoint": "subject",
        "mapping": {
            "S2703_C02_002E": "Private!!Total!!Under 19",
            "S2703_C03_002E": "Private!!Covered!!Under 19",
            "S2704_C02_002E": "Public!!Total!!Under 19",
            "S2704_C03_002E": "Public!!Covered!!Under 19"
        }
    }
}

# --- 3. EXECUTION ENGINE ---
def run_nemours_master_pull():
    print(f"🚀 Generating Master Profile for Nemours (Year: {YEAR})...")
    with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:
        for sheet, cfg in TABS_CONFIG.items():
            vars = "NAME," + ",".join(cfg['mapping'].keys())
            endpoint_path = f"/{cfg['endpoint']}" if cfg['endpoint'] else ""
            url = f"https://api.census.gov/data/{YEAR}/acs/acs5{endpoint_path}?get={vars}&for=zip%20code%20tabulation%20area:*&key={CENSUS_API_KEY}"

            r = requests.get(url)
            if r.status_code == 200:
                df = pd.DataFrame(r.json()[1:], columns=r.json()[0])
                df_filtered = df[df['zip code tabulation area'].isin(TARGET_ZIPS)].copy()

                # Numeric Clean-up
                numeric_cols = list(cfg['mapping'].keys())
                df_filtered[numeric_cols] = df_filtered[numeric_cols].apply(pd.to_numeric, errors='coerce')

                df_filtered.rename(columns=cfg['mapping'], inplace=True)
                df_filtered.to_excel(writer, sheet_name=sheet, index=False)
                print(f"   ✅ Tab '{sheet}' recorded with {len(df_filtered)} ZIPs.")
            else:
                print(f"   ❌ FAILED '{sheet}': {r.status_code}")

    print("\n✅ COMPLETE. Your comprehensive Nemours Market Profile is ready.")
    files.download(OUTPUT_FILE)

run_nemours_master_pull()
# Out:
# 🚀 Generating Master Profile for Nemours (Year: 2023)...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# ...

# %%
import pandas as pd
import requests
from google.colab import files

# --- 1. SETTINGS ---
CENSUS_API_KEY = "ace5105fd94a5e8021b2b6913f15b6a26f0b9b50"
OUTPUT_FILE = "Nemours_Market_Profile_Final.xlsx"
YEAR = "2023" # Change the this to current year to get most recent data

# Your deduplicated ZIP list
TARGET_ZIPS = ['08001', '08002', '08003', '08004', '08007', '08009', '08010', '08011', '08012', '08014', '08015', '08016', '08018', '08019', '08020', '08021', '08022', '08023', '08025', '08026', '08027', '08028', '08029', '08030', '08031', '08032', '08033', '08034', '08035', '08036', '08038', '08039', '08041', '08042', '08043', '08045', '08046', '08048', '08049', '08051', '08052', '08053', '08054', '08055', '08057', '08059', '08060', '08061', '08062', '08063', '08064', '08065', '08066', '08067', '08068', '08069', '08070', '08071', '08072', '08073', '08074', '08075', '08076', '08077', '08078', '08079', '08080', '08081', '08083', '08084', '08085', '08086', '08088', '08089', '08090', '08091', '08093', '08094', '08095', '08096', '08097', '08098', '08099', '08101', '08102', '08103', '08104', '08105', '08106', '08107', '08108', '08109', '08110', '08224', '08302', '08311', '08312', '08313', '08314', '08315', '08316', '08318', '08320', '08321', '08322', '08323', '08324', '08327', '08328', '08329', '08332', '08343', '08344', '08345', '08347', '08348', '08349', '08352', '08353', '08360', '08361', '08362', '08505', '08511', '08515', '08518', '08554', '08562', '08640', '08641', '18039', '18041', '18054', '18070', '18073', '18074', '18076', '18077', '18081', '18084', '18901', '18910', '18911', '18912', '18913', '18914', '18915', '18916', '18917', '18918', '18920', '18921', '18922', '18923', '18924', '18925', '18926', '18927', '18928', '18929', '18930', '18931', '18932', '18933', '18934', '18935', '18936', '18938', '18940', '18942', '18943', '18944', '18946', '18947', '18949', '18950', '18951', '18953', '18954', '18955', '18956', '18957', '18958', '18960', '18962', '18963', '18964', '18966', '18968', '18969', '18970', '18971', '18972', '18974', '18976', '18977', '18979', '18980', '18981', '19001', '19002', '19003', '19004', '19006', '19007', '19008', '19009', '19010', '19012', '19013', '19014', '19015', '19016', '19017', '19018', '19019', '
            "S1901_C01_002E": "Households!!Less than $10k",
            "S1901_C01_003E": "Households!!$10k to $14,999",
            "S1901_C01_004E": "Households!!$15k to $24,999",
            "S1901_C01_005E": "Households!!$25k to $34,999",
            "S1901_C01_006E": "Households!!$35k to $49,999",
            "S1901_C01_007E": "Households!!$50k to $74,999",
            "S1901_C01_008E": "Households!!$75k to $99,999",
            "S1901_C01_009E": "Households!!$100k to $149,999",
            "S1901_C01_010E": "Households!!$150k to $199,999",
            "S1901_C01_011E": "Households!!$200k or more",
            "S1901_C01_012E": "Median income (dollars)",
            "S1901_C01_013E": "Mean income (dollars)"
        }
    },
    "Race": {
        "endpoint": "profile",
        "mapping": {
            "DP05_0037E": "Est!!White",
            "DP05_0037PE": "Pct!!White",
            "DP05_0038E": "Est!!Black or African American",
            "DP05_0038PE": "Pct!!Black or African American",
            "DP05_0039E": "Est!!AIAN",
            "DP05_0039PE": "Pct!!AIAN",
            "DP05_0047E": "Est!!Asian",
            "DP05_0047PE": "Pct!!Asian",
            "DP05_0055E": "Est!!NHPI",
            "DP05_0055PE": "Pct!!NHPI",
            "DP05_0060E": "Est!!Other Race",
            "DP05_0060PE": "Pct!!Other Race",
            "DP05_0061E": "Est!!Two or More",
            "DP05_0061PE": "Pct!!Two or More"
        }
    },
    "Insurance_Pediatric": {
        "endpoint": "subject",
        "mapping": {
            "S2703_C02_002E": "Private!!Total!!Under 19",
            "S2703_C03_002E": "Private!!Covered!!Under 19",
            "S2703_C04_002E": "Private!!Not Covered!!Under 19",
            "S2704_C02_002E": "Public!!Total!!Under 19",
            "S2704_C03_002E": "Public!!Covered!!Under 19",
            "S2704_C04_002E": "Public!!Not Covered!!Under 19"
        }
    }
}

# --- 3. PROCESSING ENGINE ---
def run_nemours_data_pull():
    print(f"Starting Census Data Pull for Nemours Project (Year: {YEAR})...")

    with pd.ExcelWriter(OUTPUT_FILE, engine='openpyxl') as writer:
        for sheet_name, cfg in TABS_CONFIG.items():
            variables = "NAME," + ",".join(cfg['mapping'].keys())

            # Note: acs5 is used to ensure coverage for all ZIP codes in your catchment area
            url = f"https://api.census.gov/data/{YEAR}/acs/acs5/{cfg['endpoint']}?get={variables}&for=zip%20code%20tabulation%20area:*&key={CENSUS_API_KEY}"

            print(f"Fetching {sheet_name}...")
            r = requests.get(url)

            if r.status_code == 200:
                data = r.json()
                df = pd.DataFrame(data[1:], columns=data[0])
                df.rename(columns={'zip code tabulation area': 'Zip_Code'}, inplace=True)

                # Filter for Nemours Target Catchment
                df_filtered = df[df['Zip_Code'].isin(TARGET_ZIPS)].copy()

                # Clean numbers
                numeric_cols = list(cfg['mapping'].keys())
                df_filtered[numeric_cols] = df_filtered[numeric_cols].apply(pd.to_numeric, errors='coerce')

                # Rename columns based on your specific requirements
                df_filtered.rename(columns=cfg['mapping'], inplace=True)

                df_filtered.to_excel(writer, sheet_name=sheet_name, index=False)
                print(f"   Success: {len(df_filtered)} ZIPs recorded.")
            else:
                print(f"   ERROR {r.status_code} on {sheet_name}: {r.text}")

    print(f"\n✅ COMPLETE. File generated: {OUTPUT_FILE}")
    files.download(OUTPUT_FILE)

run_nemours_data_pull()
# Out:
# Starting Census Data Pull for Nemours Project (Year: 2023)...
# Fetching Age_Sex...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ...
